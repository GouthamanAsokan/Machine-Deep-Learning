# %%
import pandas as pd
a=[[1,'Sachin Tendulkar'],[2,'MS Dhoni'],[3,'Virat Kohli']]
df=pd.DataFrame(a,columns=['SNo','Name'])
df
# Out:
#    SNo              Name
# 0    1  Sachin Tendulkar
# 1    2          MS Dhoni
# 2    3       Virat Kohli

# %%
df=df.assign(First_Name=lambda x:x['Name'].str.split(' ').str[0])
df
# Out:
#    SNo              Name First_Name
# 0    1  Sachin Tendulkar     Sachin
# 1    2          MS Dhoni         MS
# 2    3       Virat Kohli      Virat

# %%
mappings={1:'Batsman',2:'WicketKeeper',3:'Batsman'}
df['skill']=df['SNo'].map(mappings)
df
# Out:
#    SNo              Name First_Name         skill
# 0    1  Sachin Tendulkar     Sachin       Batsman
# 1    2          MS Dhoni         MS  WicketKeeper
# 2    3       Virat Kohli      Virat       Batsman

# %%
df2=pd.DataFrame(a,columns=['SNo','Name'])
df2
# Out:
#    SNo              Name
# 0    1  Sachin Tendulkar
# 1    2          MS Dhoni
# 2    3       Virat Kohli

# %%
b=[[4,'Jadeja'],[5,'Bumrah']]
df3=pd.DataFrame(b,columns=['SNo','Name'])
df3
# Out:
#    SNo    Name
# 0    4  Jadeja
# 1    5  Bumrah

# %%
df5=pd.concat([df2,df3],axis=0)
df5.reset_index(drop=True)
# Out:
#    SNo              Name
# 0    1  Sachin Tendulkar
# 1    2          MS Dhoni
# 2    3       Virat Kohli
# 3    4            Jadeja
# 4    5            Bumrah

# %%
c=[[1,'MI'],[2,'CSK'],[3,'RCB']]
df6=pd.DataFrame(c,columns=['SNo','Team'])
df6
# Out:
#    SNo Team
# 0    1   MI
# 1    2  CSK
# 2    3  RCB

# %%
df7=pd.merge(df2,df6,on='SNo',how='left')
df7
# Out:
#    SNo              Name Team
# 0    1  Sachin Tendulkar   MI
# 1    2          MS Dhoni  CSK
# 2    3       Virat Kohli  RCB
